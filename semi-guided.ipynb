# %%
from sklearn.metrics import roc_curve
from sklearn.model_selection import GridSearchCV
from sklearn.naive_bayes import GaussianNB
from pathlib import Path
from sklearn.datasets import make_classification
from sklearn.neighbors import KNeighborsClassifier
import pandas as pd
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split
import seaborn as sns
from imblearn.over_sampling import SMOTE
import imblearn
from imblearn.under_sampling import RandomUnderSampler
from sklearn import metrics
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_squared_error
from math import sqrt
from sklearn.metrics import roc_auc_score
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_selection import SelectKBest, f_classif
# Out:
# /Users/yugyeongkim/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
#DT 
df = pd.DataFrame(columns = ["ACC","RMSE","FPR","FNR","F1","AUC-ROC","Precision","Recall","TN","FP","FN","TP","filename","feature"])
accul = []
RMSEl = []
FPRl = []
FNRl = []
F1_scorel = []
acc_roc1 = []
Precisionl = []
Recalll = []
TNl = []
FPl = []
FNl = []
TPl = []
filenamel=[]
featurel=[]

files = ['animals','human','machine']
features = [10,20,30,40]
for file in files:
    for feature in features:
        for i in range(1, 11):
            train = pd.read_csv("test_train/binary_train/"+file+"/together/"+file+"_{n}.csv".format(n=i))
            test = pd.read_csv("test_train/binary_test/"+file+"/together/"+file+"_{n}.csv".format(n=i))


            X_train = train.iloc[: , 2:122]
            y_train = train.iloc[:,122:123]
            X_test = test.iloc[: , 2:122]
            y_test = test.iloc[:,122:123]

            selector = SelectKBest(f_classif, k=feature)
            selector.fit(X_train, y_train)

            X_new = selector.transform(X_train)
            vector_names = X_train.columns[selector.get_support(indices=True)].tolist()

            X_train = X_train[vector_names]
            X_test = X_test[vector_names]



            dtmodel = DecisionTreeClassifier(max_depth=10,min_samples_split=39,random_state=500).fit(X_train,y_train)
            YPred = dtmodel.predict(X_test)
            probs = dtmodel.predict_proba(X_test)[:,1]
            false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test,probs)
            auc_score = roc_auc_score(y_test, probs)

            accuracy = accuracy_score(y_test,YPred)
            rmse = sqrt(mean_squared_error(y_test, YPred))
            TN, FP, FN, TP = confusion_matrix(y_test, YPred).ravel()
            TPR = TP/(TP+FN)
            TNR = TN/(TN+FP) 
            FPR = FP/(FP+TN)
            FNR = FN/(TP+FN)


            f1_score = metrics.f1_score(y_test, YPred)
            Precision = metrics.precision_score(y_test, YPred)
            Recall = metrics.recall_score(y_test, YPred)


            accul.append(accuracy)
            RMSEl.append(rmse)
            FPRl.append(FPR)
            FNRl.append(FNR)
            F1_scorel.append(f1_score)
            acc_roc1.append(auc_score)
            Precisionl.append(Precision)
            Recalll.append(Recall)
            TPl.append(TP)
            TNl.append(TN)
            FPl.append(FP)
            FNl.append(FN)
            featurel.append(feature)
            filenamel.append(file)
            
df['filename'] =filenamel
df['feature']=featurel
df['TP'] = TPl
df['TN'] = TNl
df['FP'] = FPl
df['FN'] = FNl
df["ACC"] = accul
df["RMSE"] = RMSEl
df["FPR"] = FPRl
df["FNR"] = FNRl
df["F1"] = F1_scorel
df['AUC-ROC'] =acc_roc1
df["Precision"] = Precisionl
df["Recall"] = Recalll

# boxplot = df.boxplot(column=["ACC","RMSE","F1","AUC-ROC","Precision","Recall"])
# plt.title('Decision Tree machine delta', size = 15)
# plt.xticks(size = 11)
# plt.yticks(size = 15)
#plt.savefig('feature_selection/new/DT.png',dpi=300,bbox_inches='tight')
df.to_csv("result/together/DT_together.csv",index=False)
df
# Out:
# /Users/yugyeongkim/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# /Users/yugyeongkim/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# /Users/yugyeongkim/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# ...

# %%
#SVM(RBF)
df = pd.DataFrame(columns = ["ACC","RMSE","FPR","FNR","F1","AUC-ROC","Precision","Recall","TN","FP","FN","TP","filename","feature"])
accul = []
RMSEl = []
FPRl = []
FNRl = []
F1_scorel = []
acc_roc1 = []
Precisionl = []
Recalll = []
TNl = []
FPl = []
FNl = []
TPl = []
filenamel=[]
featurel=[]

files = ['animals','human','machine']
features = [10,20,30,40]
for file in files:
    for feature in features:
        for i in range(1, 11):
            train = pd.read_csv("test_train/binary_train/"+file+"/together/"+file+"_{n}.csv".format(n=i))
            test = pd.read_csv("test_train/binary_test/"+file+"/together/"+file+"_{n}.csv".format(n=i))


            X_train = train.iloc[: , 2:122]
            y_train = train.iloc[:,122:123]
            X_test = test.iloc[: , 2:122]
            y_test = test.iloc[:,122:123]

            selector = SelectKBest(f_classif, k=feature)
            selector.fit(X_train, y_train)

            X_new = selector.transform(X_train)
            vector_names = X_train.columns[selector.get_support(indices=True)].tolist()

            X_train = X_train[vector_names]
            X_test = X_test[vector_names]



            rbf = svm.SVC(kernel='rbf',degree=1,C=1,gamma=0.0001,probability=True).fit(X_train, y_train)
            YPred = rbf.predict(X_test)
            probs = rbf.predict_proba(X_test)[:,1]
            false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test,probs)
            auc_score = roc_auc_score(y_test, probs)


            accuracy = accuracy_score(y_test,YPred)
            rmse = sqrt(mean_squared_error(y_test, YPred))
            TN, FP, FN, TP = confusion_matrix(y_test, YPred).ravel()
            TPR = TP/(TP+FN)
            TNR = TN/(TN+FP) 
            FPR = FP/(FP+TN)
            FNR = FN/(TP+FN)
            f1_score = metrics.f1_score(y_test, YPred)
            Precision = metrics.precision_score(y_test, YPred)
            Recall = metrics.recall_score(y_test, YPred)


            accul.append(accuracy)
            RMSEl.append(rmse)
            FPRl.append(FPR)
            FNRl.append(FNR)
            F1_scorel.append(f1_score)
            acc_roc1.append(auc_score)
            Precisionl.append(Precision)
            Recalll.append(Recall)
            TPl.append(TP)
            TNl.append(TN)
            FPl.append(FP)
            FNl.append(FN)
            featurel.append(feature)
            filenamel.append(file)
df['filename'] =filenamel
df['feature']=featurel
df['TP'] = TPl
df['TN'] = TNl
df['FP'] = FPl
df['FN'] = FNl
df["ACC"] = accul
df["RMSE"] = RMSEl
df["FPR"] = FPRl
df["FNR"] = FNRl
df["F1"] = F1_scorel
df['AUC-ROC'] =acc_roc1
df["Precision"] = Precisionl
df["Recall"] = Recalll

# boxplot = df.boxplot(column=["ACC","RMSE","F1","AUC-ROC","Precision","Recall"])
# plt.title('Together SVM(RBF)', size = 15)
# plt.xticks(size = 11)
# plt.yticks(size = 15)
# plt.savefig('SVM(RBF).png',dpi=300,bbox_inches='tight')
df.to_csv("result/together/SVM(RBF)_together.csv",index=False)
# Out:
# /Users/yugyeongkim/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# /Users/yugyeongkim/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# /Users/yugyeongkim/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# ...

# %%
#RF - semi-guided model
df = pd.DataFrame(columns = ["ACC","RMSE","FPR","FNR","F1","AUC-ROC","Precision","Recall","TN","FP","FN","TP","filename","feature"])
accul = []
RMSEl = []
FPRl = []
FNRl = []
F1_scorel = []
acc_roc1 = []
Precisionl = []
Recalll = []
TNl = []
FPl = []
FNl = []
TPl = []
filenamel=[]
featurel=[]

files = ['animals','human','machine']
features = [10,20,30,40]
for file in files:
    for feature in features:
        for i in range(1, 11):
            train = pd.read_csv("test_train/binary_train/"+file+"/together/"+file+"_{n}.csv".format(n=i))
            test = pd.read_csv("test_train/binary_test/"+file+"/together/"+file+"_{n}.csv".format(n=i))


            X_train = train.iloc[: , 2:122]
            y_train = train.iloc[:,122:123]
            X_test = test.iloc[: , 2:122]
            y_test = test.iloc[:,122:123]

            selector = SelectKBest(f_classif, k=feature)
            selector.fit(X_train, y_train)

            X_new = selector.transform(X_train)
            vector_names = X_train.columns[selector.get_support(indices=True)].tolist()

            X_train = X_train[vector_names]
            X_test = X_test[vector_names]



            rf = RandomForestClassifier(n_estimators=100).fit(X_train, y_train)
            YPred = rf.predict(X_test)
            probs = rf.predict_proba(X_test)[:,1]
            false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test,probs)

            auc_score = roc_auc_score(y_test, probs)
            accuracy = accuracy_score(y_test,YPred)
            rmse = sqrt(mean_squared_error(y_test, YPred))
            TN, FP, FN, TP = confusion_matrix(y_test, YPred).ravel()
            TPR = TP/(TP+FN)
            TNR = TN/(TN+FP) 
            FPR = FP/(FP+TN)
            FNR = FN/(TP+FN)
            f1_score = metrics.f1_score(y_test, YPred)
            Precision = metrics.precision_score(y_test, YPred)
            Recall = metrics.recall_score(y_test, YPred)


            accul.append(accuracy)
            RMSEl.append(rmse)
            FPRl.append(FPR)
            FNRl.append(FNR)
            F1_scorel.append(f1_score)
            acc_roc1.append(auc_score)
            Precisionl.append(Precision)
            Recalll.append(Recall)
            TPl.append(TP)
            TNl.append(TN)
            FPl.append(FP)
            FNl.append(FN)
            featurel.append(feature)
            filenamel.append(file)
df['filename'] =filenamel
df['feature']=featurel
df['TP'] = TPl
df['TN'] = TNl
df['FP'] = FPl
df['FN'] = FNl
df["ACC"] = accul
df["RMSE"] = RMSEl
df["FPR"] = FPRl
df["FNR"] = FNRl
df["F1"] = F1_scorel
df['AUC-ROC'] =acc_roc1
df["Precision"] = Precisionl
df["Recall"] = Recalll

# boxplot = df.boxplot(column=["ACC","RMSE","F1","AUC-ROC","Precision","Recall"])
# plt.title('Together RF', size = 15)
# plt.xticks(size = 11)
# plt.yticks(size = 15)
# plt.savefig('feature_selection/new/together_RF.png',dpi=300,bbox_inches='tight')
df.to_csv("result/together/RF_together.csv",index=False)
# Out:
# /Users/yugyeongkim/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# /Users/yugyeongkim/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:43: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# /Users/yugyeongkim/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# ...

# %%
#Create a kNN 
df = pd.DataFrame(columns = ["ACC","RMSE","FPR","FNR","F1","AUC-ROC","Precision","Recall","TN","FP","FN","TP","filename","feature"])
accul = []
RMSEl = []
FPRl = []
FNRl = []
F1_scorel = []
acc_roc1 = []
Precisionl = []
Recalll = []
TNl = []
FPl = []
FNl = []
TPl = []
filenamel=[]
featurel=[]

files = ['animals','human','machine']
features = [10,20,30,40]
for file in files:
    for feature in features:
        for i in range(1, 11):
            train = pd.read_csv("test_train/binary_train/"+file+"/together/"+file+"_{n}.csv".format(n=i))
            test = pd.read_csv("test_train/binary_test/"+file+"/together/"+file+"_{n}.csv".format(n=i))


            X_train = train.iloc[: , 2:122]
            y_train = train.iloc[:,122:123]
            X_test = test.iloc[: , 2:122]
            y_test = test.iloc[:,122:123]

            selector = SelectKBest(f_classif, k=feature)
            selector.fit(X_train, y_train)

            X_new = selector.transform(X_train)
            vector_names = X_train.columns[selector.get_support(indices=True)].tolist()

            X_train = X_train[vector_names]
            X_test = X_test[vector_names]



            knn = KNeighborsClassifier(n_neighbors=2,metric='euclidean').fit(X_train, y_train)
            YPred = knn.predict(X_test)
            probs = knn.predict_proba(X_test)[:,1]
            false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test,probs)
            auc_score = roc_auc_score(y_test, probs)

            accuracy = accuracy_score(y_test,YPred)
            rmse = sqrt(mean_squared_error(y_test, YPred))
            TN, FP, FN, TP = confusion_matrix(y_test, YPred).ravel()
            TPR = TP/(TP+FN)
            TNR = TN/(TN+FP) 
            FPR = FP/(FP+TN)
            FNR = FN/(TP+FN)
            f1_score = metrics.f1_score(y_test, YPred)
            Precision = metrics.precision_score(y_test, YPred)
            Recall = metrics.recall_score(y_test, YPred)


            accul.append(accuracy)
            RMSEl.append(rmse)
            FPRl.append(FPR)
            FNRl.append(FNR)
            F1_scorel.append(f1_score)
            acc_roc1.append(auc_score)
            Precisionl.append(Precision)
            Recalll.append(Recall)
            TPl.append(TP)
            TNl.append(TN)
            FPl.append(FP)
            FNl.append(FN)
            featurel.append(feature)
            filenamel.append(file)
df['filename'] =filenamel
df['feature']=featurel
df['TP'] = TPl
df['TN'] = TNl
df['FP'] = FPl
df['FN'] = FNl
df["ACC"] = accul
df["RMSE"] = RMSEl
df["FPR"] = FPRl
df["FNR"] = FNRl
df["F1"] = F1_scorel
df['AUC-ROC'] =acc_roc1
df["Precision"] = Precisionl
df["Recall"] = Recalll

# boxplot = df.boxplot(column=["ACC","RMSE","F1","AUC-ROC","Precision","Recall"])
# plt.title('Together knn', size = 15)
# plt.xticks(size = 11)
# plt.yticks(size = 15)
# plt.savefig('feature_selection/new/together_knn.png',dpi=300,bbox_inches='tight')
df.to_csv("result/together/kNN_together.csv",index=False)
# Out:
# /Users/yugyeongkim/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# /Users/yugyeongkim/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:43: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# /Users/yugyeongkim/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# ...

# %%
#Create a svm poly Classifier
df = pd.DataFrame(columns = ["ACC","RMSE","FPR","FNR","F1","AUC-ROC","Precision","Recall","TN","FP","FN","TP","filename","feature"])
accul = []
RMSEl = []
FPRl = []
FNRl = []
F1_scorel = []
acc_roc1 = []
Precisionl = []
Recalll = []
TNl = []
FPl = []
FNl = []
TPl = []
filenamel=[]
featurel=[]

files = ['animals','human','machine']
features = [10,20,30,40]
for file in files:
    for feature in features:
        for i in range(1, 11):
            train = pd.read_csv("test_train/binary_train/"+file+"/together/"+file+"_{n}.csv".format(n=i))
            test = pd.read_csv("test_train/binary_test/"+file+"/together/"+file+"_{n}.csv".format(n=i))


            X_train = train.iloc[: , 2:122]
            y_train = train.iloc[:,122:123]
            X_test = test.iloc[: , 2:122]
            y_test = test.iloc[:,122:123]

            selector = SelectKBest(f_classif, k=feature)
            selector.fit(X_train, y_train)

            X_new = selector.transform(X_train)
            vector_names = X_train.columns[selector.get_support(indices=True)].tolist()

            X_train = X_train[vector_names]
            X_test = X_test[vector_names]



            poly = svm.SVC(kernel='poly',degree=2,gamma=0.001,probability=True).fit(X_train, y_train)
            YPred = poly.predict(X_test)
            probs = poly.predict_proba(X_test)[:,1]
            false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test,probs)
            auc_score = roc_auc_score(y_test, probs)

            accuracy = accuracy_score(y_test,YPred)
            rmse = sqrt(mean_squared_error(y_test, YPred))
            TN, FP, FN, TP = confusion_matrix(y_test, YPred).ravel()
            TPR = TP/(TP+FN)
            TNR = TN/(TN+FP) 
            FPR = FP/(FP+TN)
            FNR = FN/(TP+FN)
            f1_score = metrics.f1_score(y_test, YPred)
            Precision = metrics.precision_score(y_test, YPred)
            Recall = metrics.recall_score(y_test, YPred)


            accul.append(accuracy)
            RMSEl.append(rmse)
            FPRl.append(FPR)
            FNRl.append(FNR)
            F1_scorel.append(f1_score)
            acc_roc1.append(auc_score)
            Precisionl.append(Precision)
            Recalll.append(Recall)
            TPl.append(TP)
            TNl.append(TN)
            FPl.append(FP)
            FNl.append(FN)
            featurel.append(feature)
            filenamel.append(file)
df['filename'] =filenamel
df['feature']=featurel
df['TP'] = TPl
df['TN'] = TNl
df['FP'] = FPl
df['FN'] = FNl
df["ACC"] = accul
df["RMSE"] = RMSEl
df["FPR"] = FPRl
df["FNR"] = FNRl
df["F1"] = F1_scorel
df['AUC-ROC'] =acc_roc1
df["Precision"] = Precisionl
df["Recall"] = Recalll

# boxplot = df.boxplot(column=["ACC","RMSE","F1","AUC-ROC","Precision","Recall"])
# plt.xticks(size = 11)
# plt.yticks(size = 15)
# plt.savefig('feature_selection/new/together_poly.png',dpi=300,bbox_inches='tight')

df.to_csv("result/together/SVM(Poly)_together.csv",index=False)

# %%
#Create NB
df = pd.DataFrame(columns = ["ACC","RMSE","FPR","FNR","F1","AUC-ROC","Precision","Recall","TN","FP","FN","TP","filename","feature"])
accul = []
RMSEl = []
FPRl = []
FNRl = []
F1_scorel = []
acc_roc1 = []
Precisionl = []
Recalll = []
TNl = []
FPl = []
FNl = []
TPl = []
filenamel=[]
featurel=[]

files = ['animals','human','machine']
features = [10,20,30,40]
for file in files:
    for feature in features:
        for i in range(1, 11):
            train = pd.read_csv("test_train/binary_train/"+file+"/together/"+file+"_{n}.csv".format(n=i))
            test = pd.read_csv("test_train/binary_test/"+file+"/together/"+file+"_{n}.csv".format(n=i))


            X_train = train.iloc[: , 2:122]
            y_train = train.iloc[:,122:123]
            X_test = test.iloc[: , 2:122]
            y_test = test.iloc[:,122:123]

            selector = SelectKBest(f_classif, k=feature)
            selector.fit(X_train, y_train)

            X_new = selector.transform(X_train)
            vector_names = X_train.columns[selector.get_support(indices=True)].tolist()

            X_train = X_train[vector_names]
            X_test = X_test[vector_names]



            gnb = GaussianNB().fit(X_train, y_train)
            y_pred = gnb.predict(X_test)

            probs = gnb.predict_proba(X_test)[:,1]
            false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test,probs)
            auc_score = roc_auc_score(y_test, probs)



            accuracy = accuracy_score(y_test,y_pred)
            rmse = sqrt(mean_squared_error(y_test, y_pred))
            TN, FP, FN, TP = confusion_matrix(y_test, y_pred).ravel()
            TPR = TP/(TP+FN)
            TNR = TN/(TN+FP) 
            FPR = FP/(FP+TN)
            FNR = FN/(TP+FN)
            f1_score = metrics.f1_score(y_test, y_pred)
            Precision = metrics.precision_score(y_test, y_pred)
            Recall = metrics.recall_score(y_test, y_pred)


            accul.append(accuracy)
            RMSEl.append(rmse)
            FPRl.append(FPR)
            FNRl.append(FNR)
            F1_scorel.append(f1_score)
            acc_roc1.append(auc_score)
            Precisionl.append(Precision)
            Recalll.append(Recall)
            TPl.append(TP)
            TNl.append(TN)
            FPl.append(FP)
            FNl.append(FN)
            featurel.append(feature)
            filenamel.append(file)

df['filename'] =filenamel
df['feature']=featurel
df['TP'] = TPl
df['TN'] = TNl
df['FP'] = FPl
df['FN'] = FNl
df["ACC"] = accul
df["RMSE"] = RMSEl
df["FPR"] = FPRl
df["FNR"] = FNRl
df["F1"] = F1_scorel
df['AUC-ROC'] =acc_roc1
df["Precision"] = Precisionl
df["Recall"] = Recalll

# boxplot = df.boxplot(column=["ACC","RMSE","F1","AUC-ROC","Precision","Recall"])
# plt.xticks(size = 11)
# plt.yticks(size = 15)
# plt.savefig('feature_selection/new/together_NB.png',dpi=300,bbox_inches='tight')

df.to_csv("result/together/NB_together.csv",index=False)

# %%
,
